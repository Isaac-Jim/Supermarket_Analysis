# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('supermarket_sales - Sheet1.csv')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#checking for null values
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
#dropping the invoice column
df.drop(columns='Invoice ID',inplace= True)

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# ...

# %%
df['City'].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df['Unit price'].unique()
# Out:
# array([74.69, 15.28, 46.33, 58.22, 86.31, 85.39, 68.84, 73.56, 36.26,
#        54.84, 14.48, 25.51, 46.95, 43.19, 71.38, 93.72, 68.93, 72.61,
#        54.67, 40.3 , 86.04, 87.98, 33.2 , 34.56, 88.63, 52.59, 33.52,
#        87.67, 88.36, 24.89, 94.13, 78.07, 83.78, 96.58, 99.42, 68.12,
#        62.62, 60.88, 54.92, 30.12, 86.72, 56.11, 69.12, 98.7 , 15.37,
#        93.96, 56.69, 20.01, 18.93, 82.63, 91.4 , 44.59, 17.87, 15.43,
#        16.16, 85.98, 44.34, 89.6 , 72.35, 30.61, 24.74, 55.73, 55.07,
#        15.81, 75.74, 15.87, 33.47, 97.61, 78.77, 18.33, 89.48, 62.12,
#        48.52, 75.91, 74.67, 41.65, 49.04, 78.31, 20.38, 99.19, 96.68,
#        19.25, 80.36, 48.91, 83.06, 76.52, 49.38, 42.47, 76.99, 47.38,
#        44.86, 21.98, 64.36, 89.75, 97.16, 87.87, 12.45, 52.75, 82.7 ,
#        48.71, 78.55, 23.07, 58.26, 30.35, 88.67, 27.38, 62.13, 33.98,
#        81.97, 16.49, 98.21, 72.84, 58.07, 80.79, 27.02, 21.94, 51.36,
# ...

# %%
#finding city with the greatest unit price across all Products
city_unit_price =df.groupby('City')['Unit price'].sum()
city_unit_price_df = city_unit_price.reset_index()

# %%
city_unit_price_df
# Out:
#         City  Unit price
# 0   Mandalay    18478.88
# 1  Naypyitaw    18567.76
# 2     Yangon    18625.49

# %%
plt.pie(x=city_unit_price_df['Unit price'],labels=city_unit_price_df['City'],autopct='%1.1f%%')
plt.show()

# %%
city_product =df.groupby(['City','Product line'])['Quantity'].sum()
city_product_df =city_product.reset_index()
city_product_df
# Out:
#          City            Product line  Quantity
# 0    Mandalay  Electronic accessories       316
# 1    Mandalay     Fashion accessories       297
# 2    Mandalay      Food and beverages       270
# 3    Mandalay       Health and beauty       320
# 4    Mandalay      Home and lifestyle       295
# 5    Mandalay       Sports and travel       322
# 6   Naypyitaw  Electronic accessories       333
# 7   Naypyitaw     Fashion accessories       342
# 8   Naypyitaw      Food and beverages       369
# 9   Naypyitaw       Health and beauty       277
# 10  Naypyitaw      Home and lifestyle       245
# 11  Naypyitaw       Sports and travel       265
# 12     Yangon  Electronic accessories       322
# 13     Yangon     Fashion accessories       263
# 14     Yangon      Food and beverages       313
# 15     Yangon       Health and beauty       257
# 16     Yangon      Home and lifestyle       371
# 17     Yangon       Sports and travel       333

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Product line',y='Quantity',data=city_product_df,hue='City',palette='winter')
plt.xticks(rotation =45, ha ='right')
plt.title('Total Quantity of Productlines based on City')
# Out:
# Text(0.5, 1.0, 'Total Quantity of Productlines based on City')

# %%
branch_total = df.groupby(['City','Customer type'])['Total'].sum()
branch_total_df = branch_total.reset_index()
branch_total_df
# Out:
#         City Customer type       Total
# 0   Mandalay        Member  53704.6860
# 1   Mandalay        Normal  52492.9860
# 2  Naypyitaw        Member  56881.2825
# 3  Naypyitaw        Normal  53687.4240
# 4     Yangon        Member  53637.4755
# 5     Yangon        Normal  52562.8950

# %%
sns.barplot(x='City',y='Total',hue='Customer type',data=branch_total_df)
# Out:
# <Axes: xlabel='City', ylabel='Total'>

# %%
city_quantity= df.groupby('City')['Quantity'].sum()
city_quantity_df = city_quantity.reset_index()
city_quantity_df
# Out:
#         City  Quantity
# 0   Mandalay      1820
# 1  Naypyitaw      1831
# 2     Yangon      1859

# %%
plt.pie(x=city_quantity_df['Quantity'],labels=city_quantity_df['City'],autopct='%1.1f%%')
plt.show()

# %%
#finding city with the greatest total price across all Products
city_total_price =df.groupby('City')['Total'].sum()
city_total_price_df = city_total_price.reset_index()
city_total_price_df
# Out:
#         City        Total
# 0   Mandalay  106197.6720
# 1  Naypyitaw  110568.7065
# 2     Yangon  106200.3705

# %%
plt.pie(x=city_total_price_df['Total'],autopct='%1.1f%%',labels=city_total_price_df['City'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1775d7a10>,
# ...
#  [Text(0.5634539536285844, 0.9447325770504145, 'Mandalay'),
#   Text(-1.0999999996193068, 2.8940030607887106e-05, 'Naypyitaw'),
#   Text(0.5634290098984011, -0.9447474534524598, 'Yangon')],
#  [Text(0.307338520161046, 0.5153086783911351, '32.9%'),
#   Text(-0.5999999997923491, 1.5785471240665693e-05, '34.2%'),
#   Text(0.3073249144900369, -0.5153167927922507, '32.9%')])

# %%
city_product_total =df.groupby(['City','Product line'])['Total'].sum()
city_product_total_df =city_product_total.reset_index()
city_product_total_df
# Out:
#          City            Product line       Total
# 0    Mandalay  Electronic accessories  17051.4435
# 1    Mandalay     Fashion accessories  16413.3165
# 2    Mandalay      Food and beverages  15214.8885
# 3    Mandalay       Health and beauty  19980.6600
# 4    Mandalay      Home and lifestyle  17549.1645
# 5    Mandalay       Sports and travel  19988.1990
# 6   Naypyitaw  Electronic accessories  18968.9745
# 7   Naypyitaw     Fashion accessories  21560.0700
# 8   Naypyitaw      Food and beverages  23766.8550
# 9   Naypyitaw       Health and beauty  16615.3260
# 10  Naypyitaw      Home and lifestyle  13895.5530
# 11  Naypyitaw       Sports and travel  15761.9280
# 12     Yangon  Electronic accessories  18317.1135
# 13     Yangon     Fashion accessories  16332.5085
# 14     Yangon      Food and beverages  17163.1005
# 15     Yangon       Health and beauty  12597.7530
# 16     Yangon      Home and lifestyle  22417.1955
# 17     Yangon       Sports and travel  19372.6995

# %%
plt.figure(figsize=(10,6))
plt.figure(figsize=(10,6))
sns.barplot(x='Product line',y='Total',data=city_product_total_df,hue='City',palette='YlGnBu')
plt.xticks(rotation =45, ha ='right')
plt.title('Total  price of Productlines based on City')
# Out:
# Text(0.5, 1.0, 'Total  price of Productlines based on City')

# %%
df['Date']=pd.to_datetime (df['Date'])

# %%
df['Date']=df['Date'].sort_values()

# %%
type(df['Date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['Date'].sort_values(ascending=True)
# Out:
# 856   2019-01-01
# 567   2019-01-01
# 245   2019-01-01
# 696   2019-01-01
# 523   2019-01-01
#          ...
# 158   2019-03-30
# 881   2019-03-30
# 963   2019-03-30
# 937   2019-03-30
# 474   2019-03-30
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=df ,x='Date',hue='City',y='Total',errorbar=('ci',False))
plt.xticks(rotation=45,ha='right')
plt.title('Total amount by date')
# Out:
# Text(0.5, 1.0, 'Total amount by date')

# %%
df['Days']= df['Date'].dt.day_name()

# %%
dates_with_highest_total= df.groupby('Date')['Total'].sum().sort_values(ascending=False)
dates_with_highest_total_df=dates_with_highest_total.reset_index()
best_5_total_dates= dates_with_highest_total_df.head(5)

# %%
best_5_total_dates
# Out:
#         Date      Total
# 0 2019-03-09  7474.0470
# 1 2019-02-07  7228.2105
# 2 2019-03-14  7214.6340
# 3 2019-02-15  6830.7855
# 4 2019-03-02  6560.3055

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=best_5_total_dates['Date'],y=best_5_total_dates['Total'],palette='winter')
plt.title(' Top 5 Dates with the best total sales')
# Out:
# /var/folders/zz/mtjch0cs3f5fyjxlm9h1bbd00000gn/T/ipykernel_20462/3750006962.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=best_5_total_dates['Date'],y=best_5_total_dates['Total'],palette='winter')
# Text(0.5, 1.0, ' Top 5 Dates with the best total sales')

# %%
dates_with_highest_quantity= df.groupby('Date')['Quantity'].sum().sort_values(ascending=False)
dates_with_highest_quantity_df=dates_with_highest_quantity.reset_index()
best_5_quantity_dates= dates_with_highest_quantity_df.head(5)
best_5_quantity_dates
# Out:
#         Date  Quantity
# 0 2019-02-07       128
# 1 2019-03-14       117
# 2 2019-02-15       106
# 3 2019-03-05       103
# 4 2019-03-09        99

# %%
date_tax= df.groupby('Date')['Tax 5%'].sum().sort_values(ascending=False)
date_most_tax_df=date_tax.reset_index()
top5_dates_tax= date_most_tax_df.head(5)
top5_dates_tax
# Out:
#         Date    Tax 5%
# 0 2019-03-09  355.9070
# 1 2019-02-07  344.2005
# 2 2019-03-14  343.5540
# 3 2019-02-15  325.2755
# 4 2019-03-02  312.3955

# %%
dates_with_lowest_total= df.groupby('Date')['Total'].sum().sort_values(ascending=True)
dates_with_lowest_total_df=dates_with_lowest_total.reset_index()
worst_5_total_dates= dates_with_lowest_total_df.head(5)
worst_5_total_dates
# Out:
#         Date      Total
# 0 2019-02-13   934.2375
# 1 2019-03-18  1292.8335
# 2 2019-02-21  1393.7385
# 3 2019-03-07  1438.2585
# 4 2019-02-18  1496.0295

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=worst_5_total_dates['Date'],y=worst_5_total_dates['Total'],palette='cool')
plt.title(' Top 5 Dates with the least sales')
# Out:
# /var/folders/zz/mtjch0cs3f5fyjxlm9h1bbd00000gn/T/ipykernel_20462/3349791448.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=worst_5_total_dates['Date'],y=worst_5_total_dates['Total'],palette='cool')
# Text(0.5, 1.0, ' Top 5 Dates with the least sales')

# %%
total_price_days= df.groupby(['City','Days'])['Total'].sum()
total_price_days_df = total_price_days.reset_index()

# %%
# Dictionary for day mapping
day_mapping = {
    'Monday': 1, 'Tuesday': 2, 'Wednesday': 3, 'Thursday': 4, 'Friday': 5,
    'Saturday': 6, 'Sunday': 7
}

# Create a new column 'day_num' by mapping the 'Days' column
df['day_num'] = df['Days'].map(day_mapping)

# Sort the DataFrame based on 'day_num'
df_sorted = df.sort_values('day_num')

# Create a line plot with proper order
plt.figure(figsize=(10,6))
sns.lineplot(x='Days', y='Total', data=df_sorted, sort=False,hue='City',errorbar=('ci', False))
plt.title('trend of total amount per day')
# Show the plot
plt.show()

# %%
df.groupby(['City','Days'])['Rating'].sum()
# Out:
# City       Days
# Mandalay   Friday       341.4
#            Monday       286.1
#            Saturday     404.2
#            Sunday       241.1
#            Thursday     297.1
#            Tuesday      371.1
#            Wednesday    322.6
# Naypyitaw  Friday       276.6
#            Monday       267.4
#            Saturday     390.4
#            Sunday       323.3
#            Thursday     333.6
#            Tuesday      375.4
#            Wednesday    353.2
# Yangon     Friday       365.6
#            Monday       340.7
#            Saturday     337.3
#            Sunday       368.1
#            Thursday     320.1
#            Tuesday      360.0
#            Wednesday    297.4
# Name: Rating, dtype: float64

# %%
grouped_df = df.groupby('Days')

wednesday_data = grouped_df.get_group('Wednesday')

# %%
wednesday_data['Product line'].value_counts()
# Out:
# Product line
# Food and beverages        33
# Fashion accessories       28
# Sports and travel         26
# Health and beauty         19
# Home and lifestyle        19
# Electronic accessories    18
# Name: count, dtype: int64

# %%
df.groupby(['City','Days'])['Quantity'].sum()
# Out:
# City       Days
# Mandalay   Friday       255
#            Monday       194
#            Saturday     335
#            Sunday       185
#            Thursday     254
#            Tuesday      311
#            Wednesday    286
# Naypyitaw  Friday       229
#            Monday       191
#            Saturday     281
#            Sunday       309
#            Thursday     242
#            Tuesday      306
#            Wednesday    273
# Yangon     Friday       274
#            Monday       253
#            Saturday     303
#            Sunday       284
#            Thursday     259
#            Tuesday      245
#            Wednesday    241
# Name: Quantity, dtype: int64

# %%
df.groupby(['City','Days'])['Unit price'].sum()
# Out:
# City       Days
# Mandalay   Friday       2731.58
#            Monday       2374.26
#            Saturday     3645.92
#            Sunday       1917.44
#            Thursday     2586.38
#            Tuesday      2984.83
#            Wednesday    2238.47
# Naypyitaw  Friday       2214.90
#            Monday       2128.41
#            Saturday     3102.06
#            Sunday       2424.76
#            Thursday     2736.44
#            Tuesday      2898.40
#            Wednesday    3062.79
# Yangon     Friday       2712.04
#            Monday       2713.33
#            Saturday     2585.76
#            Sunday       2908.69
#            Thursday     2537.53
#            Tuesday      2781.05
#            Wednesday    2387.09
# Name: Unit price, dtype: float64

# %%
df.groupby(['City','Days'])['cogs'].sum()
# Out:
# City       Days
# Mandalay   Friday       13731.20
#            Monday       12128.29
#            Saturday     20270.88
#            Sunday        9919.36
#            Thursday     15027.26
#            Tuesday      17961.18
#            Wednesday    12102.47
# Naypyitaw  Friday       14252.11
#            Monday       10405.06
#            Saturday     17210.45
#            Sunday       16224.52
#            Thursday     13474.62
#            Tuesday      16826.47
#            Wednesday    16910.30
# Yangon     Friday       13851.30
#            Monday       13561.01
#            Saturday     15967.06
#            Sunday       16196.97
#            Thursday     14687.88
#            Tuesday      14243.06
#            Wednesday    12635.93
# Name: cogs, dtype: float64

# %%
df.groupby(['City','Date'])['cogs'].sum()
# Out:
# City      Date
# Mandalay  2019-01-01    1463.52
#           2019-01-02    1107.43
#           2019-01-03     968.28
#           2019-01-04     486.27
#           2019-01-05     463.58
#                          ...
# Yangon    2019-03-26    1130.80
#           2019-03-27    1010.12
#           2019-03-28    1574.22
#           2019-03-29     931.06
#           2019-03-30    1257.73
# Name: cogs, Length: 263, dtype: float64

# %%
sns.pairplot(df)

# %%
rating_by_city= df.groupby('City')['Rating'].sum()

# %%
rating_by_city= rating_by_city.reset_index()

# %%
rating_by_city
# Out:
#         City  Rating
# 0   Mandalay  2263.6
# 1  Naypyitaw  2319.9
# 2     Yangon  2389.2

# %%
plt.pie(x=rating_by_city['Rating'],labels=rating_by_city['City'],autopct='%1.1f%%')
plt.show()

# %%
product_rating =df.groupby(['Product line','Gender'])['Rating'].sum()
product_rating =product_rating.reset_index()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Product line',y='Rating',data=product_rating,errorbar=('ci',False),hue='Gender',palette='viridis')
plt.xticks(rotation=45, ha= 'right')
plt.title('Rating Of the various Products')
# Out:
# Text(0.5, 1.0, 'Rating Of the various Products')

# %%
product_rating_byCity =df.groupby(['City','Product line'])['Rating'].sum()
product_rating_byCity =product_rating_byCity.reset_index()

# %%
product_rating_byCity
# Out:
#          City            Product line  Rating
# 0    Mandalay  Electronic accessories   391.4
# 1    Mandalay     Fashion accessories   416.8
# 2    Mandalay      Food and beverages   349.7
# 3    Mandalay       Health and beauty   376.3
# 4    Mandalay      Home and lifestyle   325.8
# 5    Mandalay       Sports and travel   403.6
# 6   Naypyitaw  Electronic accessories   371.1
# 7   Naypyitaw     Fashion accessories   483.6
# 8   Naypyitaw      Food and beverages   467.3
# 9   Naypyitaw       Health and beauty   363.9
# 10  Naypyitaw      Home and lifestyle   317.7
# 11  Naypyitaw       Sports and travel   316.3
# 12     Yangon  Electronic accessories   414.7
# 13     Yangon     Fashion accessories   350.8
# 14     Yangon      Food and beverages   420.7
# 15     Yangon       Health and beauty   324.3
# 16     Yangon      Home and lifestyle   450.5
# 17     Yangon       Sports and travel   428.2

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Product line',y='Rating',data=product_rating_byCity,hue='City',palette='winter')
plt.xticks(rotation=45, ha= 'right')
plt.title('Rating of the various Products across all cities')
# Out:
# Text(0.5, 1.0, 'Rating of the various Products across all cities')

# %%
df.groupby(['Gender','Product line'])['Rating'].sum().plot(kind='barh')
# Out:
# <Axes: ylabel='Gender,Product line'>

# %%
df['Payment'].value_counts()
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %%
total_sales_by_city_payment_product = df.groupby(['City', 'Payment','Product line'])['Total'].sum().unstack()
total_sales_by_city_payment_product
# Out:
# Product line           Electronic accessories  Fashion accessories  \
# City      Payment
# Mandalay  Cash                      6916.5285            5657.2110
#           Credit card               4994.4825            6029.2680
#           Ewallet                   5140.4325            4726.8375
# Naypyitaw Cash                      9646.9590            7669.0740
#           Credit card               2800.9485            6060.4425
#           Ewallet                   6521.0670            7830.5535
# Yangon    Cash                      4166.4945            4287.5070
#           Credit card               7632.5865            5245.3590
#           Ewallet                   6518.0325            6799.6425
#
# Product line           Food and beverages  Health and beauty  \
# City      Payment
# Mandalay  Cash                  2655.5760          7727.9790
#           Credit card           8575.1610          6197.9085
#           Ewallet               3984.1515          6054.7725
# ...

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(total_sales_by_city_payment_product, annot=True, fmt='.1f', cmap='winter', linewidths=0.5)
plt.title('Total Sales Heatmap by City and Payment Method')
plt.xlabel('Payment Method')
plt.ylabel('City')
plt.show()

# %%
average_product_rating_byCity =df.groupby(['City','Product line'])['Rating'].mean()
average_product_rating_byCity =average_product_rating_byCity.reset_index()
average_product_rating_byCity
# Out:
#          City            Product line    Rating
# 0    Mandalay  Electronic accessories  7.116364
# 1    Mandalay     Fashion accessories  6.722581
# 2    Mandalay      Food and beverages  6.994000
# 3    Mandalay       Health and beauty  7.100000
# 4    Mandalay      Home and lifestyle  6.516000
# 5    Mandalay       Sports and travel  6.509677
# 6   Naypyitaw  Electronic accessories  6.747273
# 7   Naypyitaw     Fashion accessories  7.440000
# 8   Naypyitaw      Food and beverages  7.080303
# 9   Naypyitaw       Health and beauty  6.998077
# 10  Naypyitaw      Home and lifestyle  7.060000
# 11  Naypyitaw       Sports and travel  7.028889
# 12     Yangon  Electronic accessories  6.911667
# 13     Yangon     Fashion accessories  6.878431
# 14     Yangon      Food and beverages  7.253448
# 15     Yangon       Health and beauty  6.900000
# 16     Yangon      Home and lifestyle  6.930769
# 17     Yangon       Sports and travel  7.257627

# %%
sns.distplot(x=average_product_rating_byCity['Rating'])
plt.xticks( rotation=45)
# Out:
# /var/folders/zz/mtjch0cs3f5fyjxlm9h1bbd00000gn/T/ipykernel_20462/3542006912.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=average_product_rating_byCity['Rating'])
# (array([6.  , 6.25, 6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  ]),
#  [Text(6.0, 0, '6.00'),
#   Text(6.25, 0, '6.25'),
#   Text(6.5, 0, '6.50'),
#   Text(6.75, 0, '6.75'),
#   Text(7.0, 0, '7.00'),
#   Text(7.25, 0, '7.25'),
#   Text(7.5, 0, '7.50'),
#   Text(7.75, 0, '7.75'),
#   Text(8.0, 0, '8.00')])

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# ...

# %%
df.dtypes
# Out:
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# Days                               object
# day_num                             int64
# dtype: object

# %%
#finding the department with profit
profit_by_department= df.groupby(['City','Product line'])['gross income'].sum().reset_index()
profit_by_department
# Out:
#          City            Product line  gross income
# 0    Mandalay  Electronic accessories      811.9735
# 1    Mandalay     Fashion accessories      781.5865
# 2    Mandalay      Food and beverages      724.5185
# 3    Mandalay       Health and beauty      951.4600
# 4    Mandalay      Home and lifestyle      835.6745
# 5    Mandalay       Sports and travel      951.8190
# 6   Naypyitaw  Electronic accessories      903.2845
# 7   Naypyitaw     Fashion accessories     1026.6700
# 8   Naypyitaw      Food and beverages     1131.7550
# 9   Naypyitaw       Health and beauty      791.2060
# 10  Naypyitaw      Home and lifestyle      661.6930
# 11  Naypyitaw       Sports and travel      750.5680
# 12     Yangon  Electronic accessories      872.2435
# 13     Yangon     Fashion accessories      777.7385
# 14     Yangon      Food and beverages      817.2905
# 15     Yangon       Health and beauty      599.8930
# 16     Yangon      Home and lifestyle     1067.4855
# ...

# %%
# Using Seaborn for a heatmap
plt.figure(figsize=(10, 6))
sns.barplot(data=profit_by_department, x='Product line',y='gross income',errorbar=('ci',False),palette='seismic')
plt.title('Barchart of Gross Income by Product Line ')
plt.xlabel('Product Line')
plt.ylabel('Gross Income')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/zz/mtjch0cs3f5fyjxlm9h1bbd00000gn/T/ipykernel_20462/1461067471.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=profit_by_department, x='Product line',y='gross income',errorbar=('ci',False),palette='seismic')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=profit_by_department,x='Product line',y='gross income',hue='City',palette='winter')
#plt.title('Heatmap of Gross Income by Product Line and City')
#plt.xlabel('Product Line')
#plt.ylabel('City')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# ...

# %%
print(df.dtypes)
# Out:
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# Days                               object
# day_num                             int64
# dtype: object

# %%
df.groupby(['City','Days'])['cogs'].mean().unstack()
# Out:
# Days           Friday      Monday    Saturday      Sunday    Thursday  \
# City
# Mandalay   269.239216  310.981795  337.848000  283.410286  341.528636
# Naypyitaw  375.055526  273.817368  318.712037  352.706957  280.721250
# Yangon     277.026000  282.521042  319.341200  311.480192  319.301739
#
# Days          Tuesday   Wednesday
# City
# Mandalay   338.890189  242.049400
# Naypyitaw  311.601296  338.206000
# Yangon     279.275686  293.858837

# %%
df.groupby(['City','Days'])['Quantity'].mean().unstack()
# Out:
# Days         Friday    Monday  Saturday    Sunday  Thursday   Tuesday  \
# City
# Mandalay   5.000000  4.974359  5.583333  5.285714  5.772727  5.867925
# Naypyitaw  6.026316  5.026316  5.203704  6.717391  5.041667  5.666667
# Yangon     5.480000  5.270833  6.060000  5.461538  5.630435  4.803922
#
# Days       Wednesday
# City
# Mandalay    5.720000
# Naypyitaw   5.460000
# Yangon      5.604651

# %%
df.groupby(['City','Days'])['Unit price'].mean().unstack()
# Out:
# Days          Friday     Monday   Saturday     Sunday   Thursday    Tuesday  \
# City
# Mandalay   53.560392  60.878462  60.765333  54.784000  58.781364  56.317547
# Naypyitaw  58.286842  56.010789  57.445556  52.712174  57.009167  53.674074
# Yangon     54.240800  56.527708  51.715200  55.936346  55.163696  54.530392
#
# Days       Wednesday
# City
# Mandalay   44.769400
# Naypyitaw  61.255800
# Yangon     55.513721
